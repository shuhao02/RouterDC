# %%
import json
import os
from matplotlib import pyplot as plt


# with open("/data/home/chensh/projects/LLM_router/logs/paper_result/seed_search/clw_0/slw_0_clw_0_clw_2_0_cos_tk_3_lk_3_lr_5e-5_step_1000_t_1_seed_42/training_log.json", 'r') as f:
#     training_result = json.load(f)

# with open("/data/home/chensh/projects/LLM_router/logs/paper_result/seed_search/clw_1/slw_0_clw_1_clw_2_0_cos_tk_3_lk_3_lr_5e-5_step_1000_t_1_seed_42/training_log.json", 'r') as f:
#     training_result = json.load(f)

with open("/data/home/chensh/projects/LLM_router/logs/paper_result/supervised/dot_lr_5e-5_step_1000_t_1_seed_5/training_log.json", 'r') as f:
    training_result = json.load(f)



step = 10
print(training_result[1].keys())
# .keys()

# dataset_prefix1 = "./datasets/llm_numbers/model_3_2_cluster/"
# dataset_prefix2 = "./datasets/llm_numbers/model_3_2/"

# dataset_prefix1 = "./datasets/num_cluster/cluster_2/"
# dataset_prefix2 = "./datasets/split2_model7/"

# dataset_prefix1 = "./datasets/split2_model5_2_cluster_3/"
# dataset_prefix2 = "./datasets/split2_model5_2/"

# dataset_prefix1 = "./datasets/split2_model8_cluster2/"
# dataset_prefix2 = "./datasets/split2_model8/"

dataset_prefix1 = "./datasets/split2_model7_cluster/"
dataset_prefix2 = "./datasets/split2_model7/"


# dataset_prefix1 = "./datasets/split2_model8_2_cluster/"
# dataset_prefix2 = "./datasets/split2_model8_2/"

# dataset_prefix1 = "./datasets/only_gsm8k_model7/"
# dataset_prefix2 = "./datasets/split2_model7/"

# dataset_prefix1 = "./datasets/split2/"
# dataset_prefix2 = "./datasets/split2/"

# dataset_prefix1 = "./datasets/split2_model7/"
# dataset_prefix2 = "./datasets/split2_model7/"


training_result[1]
# Out:
# dict_keys(['./datasets/split2_model7_cluster/gsm8k-train.json', './datasets/split2_model7_cluster/humaneval_train.json', './datasets/split2_model7_cluster/arc_challenge_train.json', './datasets/split2_model7_cluster/cmmlu_train.json', './datasets/split2_model7_cluster/mmlu_train.json', './datasets/split2_model7/gsm8k-test.json', './datasets/split2_model7/humaneval_test.json', './datasets/split2_model7/arc_challenge_test.json', './datasets/split2_model7/cmmlu_test.json', './datasets/split2_model7/mmlu_test.json'])
# {'./datasets/split2_model7_cluster/gsm8k-train.json': [0.564,
#   0.7982999973297119],
#  './datasets/split2_model7_cluster/humaneval_train.json': [0.30434782608695654,
#   0.5834782807723335],
#  './datasets/split2_model7_cluster/arc_challenge_train.json': [0.14878048780487804,
#   0.5170731707317073],
#  './datasets/split2_model7_cluster/cmmlu_train.json': [0.1395, 0.466],
#  './datasets/split2_model7_cluster/mmlu_train.json': [0.133, 0.623],
# ...

# %%
training_result_name = dataset_prefix1 + "gsm8k-train.json"
training_result_name2 = dataset_prefix2 + "gsm8k-test.json"

plot_x = [result[training_result_name][1] for result in training_result]

plt.plot([step *i for i in range(len(plot_x))], plot_x)

plot_x = [result[training_result_name2][1] for result in training_result ]
plt.xlabel(f"{training_result_name}+{training_result_name2}")

plt.plot([step *i for i in range(len(plot_x))], plot_x)
plt.legend([f"{training_result_name} acc", f"{training_result_name2} acc"])

plt.plot([step *i for i in range(len(plot_x))], [0.6981 for i in range(len(plot_x))])

# %%
training_result_name = dataset_prefix1 + "humaneval_train.json"
training_result_name2 = dataset_prefix2 + "humaneval_test.json"
plot_x = [result[training_result_name][1] for result in training_result ]
plt.plot([step*i for i in range(len(plot_x))], plot_x)

plot_x = [result[training_result_name2][1] for result in training_result]
plt.plot([step*i for i in range(len(plot_x))], plot_x)
plt.legend([f"{training_result_name} acc", f"{training_result_name2} acc"])
plt.xlabel(f"{training_result_name}+{training_result_name2}")

plt.plot([step*i for i in range(len(plot_x))], [0.4939 for i in range(len(plot_x))])
# plt.plot([step*i for i in range(len(plot_x))], [0.4510 for i in range(len(plot_x))])

# %%
training_result_name = dataset_prefix1 + "arc_challenge_train.json"
training_result_name2 = dataset_prefix2 + "arc_challenge_test.json"
plot_x = [result[training_result_name][1] for result in training_result ]

plt.plot([step*i for i in range(len(plot_x))], plot_x)

plot_x = [result[training_result_name2][1] for result in training_result ]
plt.xlabel(f"{training_result_name}+{training_result_name2}")

plt.plot([step *i for i in range(len(plot_x))], plot_x)
plt.legend([f"{training_result_name} acc", f"{training_result_name2} acc"])

plt.plot([step *i for i in range(len(plot_x))], [0.5796 for i in range(len(plot_x))])

# %%
training_result_name = dataset_prefix1 + "cmmlu_train.json"
training_result_name2 = dataset_prefix2 + "cmmlu_test.json"

plt.plot([step *i for i in range(len(plot_x))], [result[training_result_name][1] for result in training_result ])

plot_x = [result[training_result_name2][1] for result in training_result ]
plt.xlabel(f"{training_result_name}+{training_result_name2}")

plt.plot([step *i for i in range(len(plot_x))], plot_x)
plt.legend([f"{training_result_name} acc", f"{training_result_name2} acc"])

plt.plot([step *i for i in range(len(plot_x))], [0.5249 for i in range(len(plot_x))])
# plt.plot([step *i for i in range(len(plot_x))], [0.4967 for i in range(len(plot_x))])

# %%
training_result_name = dataset_prefix1 + "mmlu_train.json"
training_result_name2 = dataset_prefix2 + "mmlu_test.json"

plot_x = [result[training_result_name][1] for result in training_result ]
plt.plot([step *i for i in range(len(plot_x))], plot_x)

plot_x = [result[training_result_name2][1] for result in training_result ]
plt.xlabel(f"{training_result_name}+{training_result_name2}")

plt.plot([step *i for i in range(len(plot_x))], plot_x)
plt.legend([f"{training_result_name} acc", f"{training_result_name2} acc"])

plt.plot([step *i for i in range(len(plot_x))], [0.6459 for i in range(len(plot_x))])
# plt.plot([step *i for i in range(len(plot_x))], [0.6214 for i in range(len(plot_x))])

# %%
# compute the average 

# with open("/data/home/chensh/projects/LLM_router/logs/paper_result/supervised/dot_lr_5e-5_step_1000_t_1_seed_5/training_log.json", 'r') as f:
#     training_result = json.load(f)


with open("/data/home/chensh/projects/LLM_router/logs/paper_result/seed_search/clw_1/slw_0_clw_1_clw_2_0_cos_tk_3_lk_3_lr_5e-5_step_1000_t_1_seed_42/training_log.json", 'r') as f:
    training_result = json.load(f)


import numpy as np
plot_x = [ np.array(list(result.values()))[:5:,1].mean() for result in training_result ]
plt.plot([step *i for i in range(len(plot_x))], plot_x)

plot_x = [ np.array(list(result.values()))[-5:,1].mean() for result in training_result ]
plt.plot([step *i for i in range(len(plot_x))], plot_x)

plt.legend([f"train acc", f"test acc"])

# plt.plot([step *i for i in range(len(plot_x))], [0.6214 for i in range(len(plot_x))])

# %%
# np.array(list(training_result[-1].values()))[5:,1].mean()
# training_result[0]
# np.array(list(result.values()))[-5:,1].mean()

training_result
# Out:
# [{'./datasets/split2_model7_cluster/gsm8k-train.json': [0.019,
#    0.4815999984741211],
#   './datasets/split2_model7_cluster/humaneval_train.json': [0.2, 0.5],
#   './datasets/split2_model7_cluster/arc_challenge_train.json': [0.06829268292682927,
#    0.5329268292682927],
#   './datasets/split2_model7_cluster/cmmlu_train.json': [0.0925, 0.478],
#   './datasets/split2_model7_cluster/mmlu_train.json': [0.0645, 0.6435],
#   './datasets/split2_model7/gsm8k-test.json': [0.04094010614101592,
#    0.4794541287367953],
#   './datasets/split2_model7/humaneval_test.json': [0.22448979591836735,
#    0.4510204159483618],
#   './datasets/split2_model7/arc_challenge_test.json': [0.07386363636363637,
#    0.5255681818181818],
#   './datasets/split2_model7/cmmlu_test.json': [0.09179856115107914,
#    0.5093525179856115],
#   './datasets/split2_model7/mmlu_test.json': [0.05910277711844292,
#    0.6275812959886067]},
#  {'./datasets/split2_model7_cluster/gsm8k-train.json': [0.09,
# ...

# %%
import json
import os
from matplotlib import pyplot as plt


with open("/data/home/chensh/projects/LLM_router/logs/paper_result/seed_search/clw_0/slw_0_clw_0_clw_2_0_cos_tk_3_lk_3_lr_5e-5_step_1000_t_1_seed_42/training_log.json", 'r') as f:
    training_result_clw_0 = json.load(f)

with open("/data/home/chensh/projects/LLM_router/logs/paper_result/seed_search/clw_1/slw_0_clw_1_clw_2_0_cos_tk_3_lk_3_lr_5e-5_step_1000_t_1_seed_42/training_log.json", 'r') as f:
    training_result_clw_1 = json.load(f)

training_result_name = dataset_prefix1 + "gsm8k-train.json"
training_result_name2 = dataset_prefix2 + "gsm8k-test.json"

plt.figure(figsize=(5, 5))
colors = [u'#1f77b4', u'#ff7f0e', u'#2ca02c', u'#d62728', u'#9467bd', u'#8c564b', u'#e377c2', u'#7f7f7f', u'#bcbd22', u'#17becf']
# For clw=0
training_curve_clw_1 = [45] + [result[training_result_name][1] * 100 for result in training_result_clw_1]
clw_1_training_line = plt.plot([step *i for i in range(len(training_curve_clw_1))], training_curve_clw_1, color=colors[1])
testing_curve_clw_1 = [45] + [result[training_result_name2][1] * 100 for result in training_result_clw_1]
clw_1_testing_line = plt.plot([step *i for i in range(len(testing_curve_clw_1))], testing_curve_clw_1, color=colors[1], linestyle='--')

training_curve_clw_0 = [49.48] + [result[training_result_name][1] * 100 for result in training_result_clw_0]
clw_0_training_line = plt.plot([step *i for i in range(len(training_curve_clw_0))], training_curve_clw_0 , color=colors[0])
testing_curve_clw_0 = [49.48] +  [result[training_result_name2][1] * 100 for result in training_result_clw_0]
clw_0_testing_line = plt.plot([step *i for i in range(len(testing_curve_clw_0))], testing_curve_clw_0, color=colors[0], linestyle='--')

plt.legend([ r"RouterDC: Training", r"RouterDC: Testing", r"RouterDC(w/o $\mathcal{L}_{\text{sample-sample}}$): Training", r"RouterDC(w/o $\mathcal{L}_{\text{sample-sample}}$): Testing",], fontsize=11)


plt.xlabel(r"$\#$Iteration", fontsize=17)
plt.ylabel(r"Accuracy(%)", fontsize=17)
# plt.savefig("/data/home/chensh/projects/LLM_router/figures/Acc_curve.pdf", dpi=800, bbox_inches = 'tight')
# plt.plot([step *i for i in range(len(plot_x))], [0.6981 for i in range(len(plot_x))], color=colors[2])
