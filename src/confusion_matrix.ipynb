# %%
import pandas as pd
import numpy as np

dataset_paths = ["../datasets/split2_model7_cluster/mmlu_train.json","../datasets/split2_model7_cluster/gsm8k-train.json", "../datasets/split2_model7_cluster/cmmlu_train.json", "../datasets/split2_model7_cluster/arc_challenge_train.json", "../datasets/split2_model7_cluster/humaneval_train.json",]

router_datasets = [pd.read_json(data_path) for data_path in dataset_paths]

for i, router_dataset in enumerate(router_datasets):
    router_dataset["dataset_id"] = i
all_router_datasets = pd.concat(router_datasets)

# value_counts = []
# for i in range(5):
#     cluster_dataset = all_router_datasets[all_router_datasets["cluster_id"]==i]
#     value_count = cluster_dataset["dataset_id"].value_counts()
#     # value_count.index = new_index
#     value_counts.append(value_count)

# for i in range(5):
#     print(value_counts[i] / value_counts[i].sum())
# print(value_counts)

value_counts = []
for i in range(5):
    cluster_dataset = all_router_datasets[all_router_datasets["dataset_id"]==i]
    value_count = cluster_dataset["cluster_id"].value_counts().sort_index()
    # value_count.index = new_index
    value_counts.append(value_count)

for i in range(5):
    print((value_counts[i] / value_counts[i].sum()))

for i in range(5):
    print((value_counts[i] / value_counts[i].sum()).tolist())
# print(value_counts)

# %%
import pandas as pd
import numpy as np

dataset_paths = ["../datasets/num_cluster/cluster_9/mmlu_train.json","../datasets/num_cluster/cluster_9/gsm8k-train.json", "../datasets/num_cluster/cluster_9/cmmlu_train.json", "../datasets/num_cluster/cluster_9/arc_challenge_train.json", "../datasets/num_cluster/cluster_9/humaneval_train.json",]

router_datasets = [pd.read_json(data_path) for data_path in dataset_paths]

for i, router_dataset in enumerate(router_datasets):
    router_dataset["dataset_id"] = i
all_router_datasets = pd.concat(router_datasets)

# value_counts = []
# for i in range(5):
#     cluster_dataset = all_router_datasets[all_router_datasets["cluster_id"]==i]
#     value_count = cluster_dataset["dataset_id"].value_counts()
#     # value_count.index = new_index
#     value_counts.append(value_count)

# for i in range(5):
#     print(value_counts[i] / value_counts[i].sum())
# print(value_counts)

value_counts = []
for i in range(5):
    cluster_dataset = all_router_datasets[all_router_datasets["dataset_id"]==i]
    value_count = cluster_dataset["cluster_id"].value_counts().sort_index()
    # value_count.index = new_index
    value_counts.append(value_count)

for i in range(5):
    print((value_counts[i] / value_counts[i].sum()))

for i in range(5):
    print((value_counts[i] / value_counts[i].sum() * 100).tolist())
# print(value_counts)
# Out:
# cluster_id
# 0    0.0475
# 1    0.0015
# 2    0.0195
# 3    0.4425
# 4    0.0015
# 5    0.0100
# 6    0.3685
# 7    0.0035
# 8    0.1055
# Name: count, dtype: float64
# cluster_id
# 0    0.460
# 1    0.001
# 2    0.018
# 3    0.003
# 5    0.464
# 6    0.040
# 8    0.014
# Name: count, dtype: float64
# cluster_id
# 2    0.0005
# 3    0.0015
# 4    0.3000
# 6    0.0005
# 7    0.6975
# Name: count, dtype: float64
# cluster_id
# 0    0.010976
# 1    0.513415
# 2    0.004878
# 3    0.004878
# 5    0.003659
# 6    0.010976
# 8    0.451220
# Name: count, dtype: float64
# cluster_id
# 2    0.400000
# 3    0.121739
# 4    0.078261
# 6    0.400000
# Name: count, dtype: float64
# [4.75, 0.15, 1.95, 44.25, 0.15, 1.0, 36.85, 0.35000000000000003, 10.549999999999999]
# [46.0, 0.1, 1.7999999999999998, 0.3, 46.400000000000006, 4.0, 1.4000000000000001]
# [0.05, 0.15, 30.0, 0.05, 69.75]
# ...

# %%
# Out:
# dataset_id
# 3    0.837134
# 0    0.147666
# 1    0.015201
# Name: count, dtype: float64
# dataset_id
# 1    0.894472
# 0    0.071357
# 3    0.029146
# 4    0.005025
# Name: count, dtype: float64
# dataset_id
# 0    0.950931
# 4    0.031303
# 1    0.009306
# 3    0.005076
# 2    0.003384
# Name: count, dtype: float64
# dataset_id
# 2    0.995002
# 0    0.004498
# 3    0.000500
# Name: count, dtype: float64
# dataset_id
# 0    0.789474
# 1    0.101675
# 4    0.087321
# 3    0.015550
# 2    0.005981
# Name: count, dtype: float64

# %%
# Out:
# cluster_id
# 0    0.0680
# 1    0.0355
# 2    0.5620
# 3    0.0045
# 4    0.3300
# Name: count, dtype: float64
# cluster_id
# 0    0.014
# 1    0.890
# 2    0.011
# 4    0.085
# Name: count, dtype: float64
# cluster_id
# 2    0.0020
# 3    0.9955
# 4    0.0025
# Name: count, dtype: float64
# cluster_id
# 0    0.940244
# 1    0.035366
# 2    0.007317
# 3    0.001220
# 4    0.015854
# Name: count, dtype: float64
# cluster_id
# 1    0.043478
# 2    0.321739
# 4    0.634783
# Name: count, dtype: float64
# [0.068, 0.0355, 0.562, 0.0045, 0.33]
# [0.014, 0.89, 0.011, 0.085]
# [0.002, 0.9955, 0.0025]
# [0.9402439024390243, 0.03536585365853658, 0.007317073170731708, 0.0012195121951219512, 0.015853658536585366]
# [0.043478260869565216, 0.3217391304347826, 0.6347826086956522]

# %%
# Out:
# pandas.core.series.Series
